# %%
import sys
sys.path.append("..")

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
from data_utils.plotting import plot_curves

# %%
df = pd.read_csv("../documentation/results/dropout_results.csv")
columns = df.columns
df = df.rename(columns={column: column.strip() for column in columns})

# %%
df
# Out:
#     epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 0       0        0.075930        0.026344               0            0.96376
# 1       1        0.042970        0.016026               0            0.95845
# 2       2        0.035391        0.012162               0            0.98265
# 3       3        0.030253        0.010395               0            0.98009
# 4       4        0.026956        0.009322               0            0.97979
# 5       5        0.025006        0.008756               0            0.97901
# 6       6        0.023605        0.008282               0            0.98213
# 7       7        0.022395        0.007950               0            0.97828
# 8       8        0.021750        0.007697               0            0.98570
# 9       9        0.020979        0.007419               0            0.98943
# 10     10        0.020482        0.007324               0            0.98505
# ...

# %%
save_base = os.path.join("..", "documentation", "plots", "dropout")
if not os.path.exists(save_base):
    os.makedirs(save_base)

# %%
plot_curves(
    [df["train/box_loss"].values, df["val/box_loss"].values], 
    titles=["Train", "Validation"], 
    plot_title="Bounding Box Loss", 
    save=True, 
    save_path=os.path.join(save_base, "box_loss.png"))

# %%
plot_curves(
    [df["train/obj_loss"].values, df["val/obj_loss"].values], 
    titles=["Train", "Validation"], 
    plot_title="Object Loss", 
    save=True, 
    save_path=os.path.join(save_base, "obj_loss.png"))

# %%
plot_curves(
    [df["metrics/precision"].values, df["metrics/recall"].values, df["metrics/mAP_0.5"].values, df["metrics/mAP_0.5:0.95"].values], 
    titles=["Precision", "Recall", "mAP@0.5", "mAP@0.5:0.95"], 
    plot_title="Metrics", 
    save=True, 
    save_path=os.path.join(save_base, "Metrics.png"))
